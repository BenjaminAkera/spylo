# %%
import requests
import matplotlib
import pandas as pd

# %%
df = pd.read_csv('result.csv')

# %%
df.head()
# Out:
#                        id                                               href  \
# 0  GCpUAcfpSUmOXKgHAOxV-A  https://platform.whereismytransport.com/api/st...
# 1  OzeptyUqgU-UH6gXAHShLA  https://platform.whereismytransport.com/api/st...
# 2  DQ3NlSt1kUuGnagHAOxWSA  https://platform.whereismytransport.com/api/st...
# 3  Ae7xlznggUOZwKgXAHSgaA  https://platform.whereismytransport.com/api/st...
# 4  uWX-b6zza0avZKgXAHSgxA  https://platform.whereismytransport.com/api/st...
#
#                 agency/id                                        agency/href  \
# 0  fzyQmSswUEetlagHAOxM4Q  https://platform.whereismytransport.com/api/ag...
# 1  Gmpaqr87U062FqgXAHR9CA  https://platform.whereismytransport.com/api/ag...
# 2  fzyQmSswUEetlagHAOxM4Q  https://platform.whereismytransport.com/api/ag...
# 3  Gmpaqr87U062FqgXAHR9CA  https://platform.whereismytransport.com/api/ag...
# 4  Gmpaqr87U062FqgXAHR9CA  https://platform.whereismytransport.com/api/ag...
#
#         agency/name agency/culture  \
# ...

# %%
df = pd.read_csv('result.csv',usecols=["name","id","agency/name","geometry/coordinates/0","geometry/coordinates/1"])

# %%
df.head()
# Out:
#                        id       agency/name  \
# 0  GCpUAcfpSUmOXKgHAOxV-A  Pioneer Easy Bus
# 1  OzeptyUqgU-UH6gXAHShLA     Kampala Taxis
# 2  DQ3NlSt1kUuGnagHAOxWSA  Pioneer Easy Bus
# 3  Ae7xlznggUOZwKgXAHSgaA     Kampala Taxis
# 4  uWX-b6zza0avZKgXAHSgxA     Kampala Taxis
#
#                                           name  geometry/coordinates/0  \
# 0          African Child, Kinawataka Road Stop                32.62814
# 1                                  Banda Stage                32.63608
# 2                                  Banda Stage                32.63581
# 3                                  Bbuto Stage                32.67552
# 4  Bethesda Medical Centre, Makerere Hill Road                32.57212
#
#    geometry/coordinates/1
# 0                 0.33408
# 1                 0.34237
# 2                 0.34222
# 3                 0.37240
# 4                 0.32915

# %%
df.shape
# Out:
# (100, 5)

# %%
df.loc[0:100,["agency/name","name"]]
# Out:
#          agency/name                                               name
# 0   Pioneer Easy Bus                African Child, Kinawataka Road Stop
# 1      Kampala Taxis                                        Banda Stage
# 2   Pioneer Easy Bus                                        Banda Stage
# 3      Kampala Taxis                                        Bbuto Stage
# 4      Kampala Taxis        Bethesda Medical Centre, Makerere Hill Road
# 5      Kampala Taxis                   Birigomututu House, Gogonya Road
# 6      Kampala Taxis                                      Bugembe Stage
# 7   Pioneer Easy Bus                                     Bugolobi Stage
# 8      Kampala Taxis                                   Bujuko Taxi Park
# 9      Kampala Taxis                                     Bukasa Muyenga
# 10     Kampala Taxis                                       Bukasa Stage
# 11     Kampala Taxis                                Bunamwaya Taxi Park
# ...

# %%
# %matplotlib inline

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffbb8d11048>,
# ...
#       dtype=object)

# %%
df = pd.read_csv('result.csv',usecols=["name"])

# %%
df.apply(pd.value_counts).plot(kind='pie',subplots='True')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ffbb8cfdf28>],
#       dtype=object)
